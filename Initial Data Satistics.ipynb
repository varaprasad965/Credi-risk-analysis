# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ms4610project"
# Out:
# /content/drive/MyDrive/ms4610project

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
 df = pd.read_csv("./Training Data_2021.csv")
 df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    application_key mvar1   mvar2  mvar3  ...  mvar45  mvar46 mvar47 default_ind
# 0           230032  1696  1.6541  0.000  ...      na       0      C           0
# 1           230033  1846  0.8095  0.000  ...      na      na      L           1
# 2           230034  1745  0.4001  0.000  ...      na       0      C           1
# 3           230035  1739  0.2193  0.000  ...       0       0      L           0
# 4           230036  1787  0.0118  0.225  ...      na      na      L           0
#
# [5 rows x 49 columns]

# %%
temp =  df.copy().replace("missing", np.NaN).replace("na", np.NaN)
for x in temp.columns:
  print(f"=================================\n {x}")
  print(temp[x].describe())
# Out:
# =================================
#  application_key
# count     83000.000000
# mean     318146.931060
# std       97179.489955
# min      230032.000000
# 25%      250781.750000
# 50%      271531.500000
# 75%      362296.250000
# max      578068.000000
# Name: application_key, dtype: float64
# =================================
#  mvar1
# count     79267
# unique      454
# top        1736
# freq        491
# Name: mvar1, dtype: object
# =================================
#  mvar2
# count    77114.000000
# mean         1.054816
# std          1.556682
# min          0.000000
# 25%          0.131800
# 50%          0.513000
# 75%          1.386200
# max         31.018100
# Name: mvar2, dtype: float64
# =================================
#  mvar3
# count    82465.000000
# mean         5.401784
# std         11.091569
# min          0.000000
# 25%          0.000000
# 50%          0.300000
# 75%          6.595000
# max        399.334000
# Name: mvar3, dtype: float64
# =================================
#  mvar4
# count    82465.000000
# mean         0.461151
# std          1.704292
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         25.754000
# Name: mvar4, dtype: float64
# =================================
#  mvar5
# count    82465.000000
# mean         1.084012
# std          5.743899
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        165.492000
# Name: mvar5, dtype: float64
# =================================
#  mvar6
# count     63299
# unique     7389
# top           0
# freq      10572
# Name: mvar6, dtype: object
# =================================
#  mvar7
# count     75326
# unique    29001
# top           0
# freq       3145
# Name: mvar7, dtype: object
# =================================
#  mvar8
# count     63291
# unique    16099
# top           0
# freq       2688
# Name: mvar8, dtype: object
# =================================
#  mvar9
# count     71318
# unique    30441
# top         297
# freq       1208
# Name: mvar9, dtype: object
# =================================
#  mvar10
# count     82465
# unique    40624
# top           0
# freq      10712
# Name: mvar10, dtype: object
# =================================
#  mvar11
# count     36283
# unique    11853
# top           0
# freq         93
# Name: mvar11, dtype: object
# =================================
#  mvar12
# count     68422
# unique    20200
# top           0
# freq       5422
# Name: mvar12, dtype: object
# =================================
#  mvar13
# count     73311
# unique    27984
# top           0
# freq      12411
# Name: mvar13, dtype: object
# =================================
#  mvar14
# count    8.300000e+04
# mean     1.894841e+05
# std      7.427382e+06
# min      0.000000e+00
# 25%      4.261300e+04
# 50%      7.234300e+04
# 75%      1.189200e+05
# max      9.910000e+08
# Name: mvar14, dtype: float64
# =================================
#  mvar15
# count      49481
# unique     33893
# top       346850
# freq         119
# Name: mvar15, dtype: object
# =================================
#  mvar16
# count     63757
# unique       12
# top           0
# freq      53796
# Name: mvar16, dtype: object
# =================================
#  mvar17
# count     66501
# unique       15
# top           0
# freq      55144
# Name: mvar17, dtype: object
# =================================
#  mvar18
# count     67641
# unique       15
# top           0
# freq      55803
# Name: mvar18, dtype: object
# =================================
#  mvar19
# count     82995
# unique       49
# top           0
# freq      30485
# Name: mvar19, dtype: int64
# =================================
#  mvar20
# count     82465
# unique       28
# top           0
# freq      47146
# Name: mvar20, dtype: object
# =================================
#  mvar21
# count    59538.000000
# mean        57.302429
# std         35.614851
# min          0.117000
# 25%         26.277000
# 50%         58.905000
# 75%         86.100000
# max       1305.250000
# Name: mvar21, dtype: float64
# =================================
#  mvar22
# count    52332.000000
# mean      4347.490308
# std       3790.531813
# min          0.000000
# 25%        655.050000
# 50%       3844.675000
# 75%       7473.407500
# max      99800.000000
# Name: mvar22, dtype: float64
# =================================
#  mvar23
# count     40689.000000
# mean       4241.010319
# std        3855.423204
# min           0.000000
# 25%         490.000000
# 50%        3611.110000
# 75%        7412.030000
# max      124533.330000
# Name: mvar23, dtype: float64
# =================================
#  mvar24
# count    63470.000000
# mean        70.640478
# std        333.609078
# min          0.000000
# 25%          9.420000
# 50%         39.300000
# 75%         75.200000
# max      27867.400000
# Name: mvar24, dtype: float64
# =================================
#  mvar25
# count     75138
# unique     5412
# top         183
# freq        386
# Name: mvar25, dtype: object
# =================================
#  mvar26
# count     72071
# unique      621
# top         183
# freq        566
# Name: mvar26, dtype: object
# =================================
#  mvar27
# count     69350
# unique      577
# top          61
# freq        610
# Name: mvar27, dtype: object
# =================================
#  mvar28
# count     82465
# unique       95
# top       30386
# freq      23321
# Name: mvar28, dtype: object
# =================================
#  mvar29
# count     82465
# unique      679
# top        3772
# freq        403
# Name: mvar29, dtype: object
# =================================
#  mvar30
# count     45012
# unique      281
# top        3711
# freq        430
# Name: mvar30, dtype: object
# =================================
#  mvar31
# count     24461
# unique      416
# top        3802
# freq        199
# Name: mvar31, dtype: object
# =================================
#  mvar32
# count     75138
# unique     2841
# top           2
# freq        320
# Name: mvar32, dtype: object
# =================================
#  mvar33
# count    81131.000000
# mean         6.983915
# std          7.625562
# min          0.083300
# 25%          1.250000
# 50%          3.916700
# 75%         10.583300
# max         76.500000
# Name: mvar33, dtype: float64
# =================================
#  mvar34
# count     82465
# unique       20
# top           0
# freq      69714
# Name: mvar34, dtype: object
# =================================
#  mvar35
# count     48132
# unique       10
# top           0
# freq      41369
# Name: mvar35, dtype: object
# =================================
#  mvar36
# count     79841
# unique       72
# top           3
# freq       9948
# Name: mvar36, dtype: object
# =================================
#  mvar37
# count     75138
# unique       57
# top           0
# freq      16245
# Name: mvar37, dtype: object
# =================================
#  mvar38
# count     82465
# unique       58
# top           2
# freq      12716
# Name: mvar38, dtype: object
# =================================
#  mvar39
# count     76671
# unique       19
# top           0
# freq      71540
# Name: mvar39, dtype: object
# =================================
#  mvar40
# count     17930
# unique    13979
# top         100
# freq       2415
# Name: mvar40, dtype: object
# =================================
#  mvar41
# count     25736
# unique    19616
# top         100
# freq        706
# Name: mvar41, dtype: object
# =================================
#  mvar42
# count     80977
# unique     1094
# top           0
# freq      25681
# Name: mvar42, dtype: object
# =================================
#  mvar43
# count     82111
# unique       58
# top           0
# freq      10318
# Name: mvar43, dtype: object
# =================================
#  mvar44
# count    74851.000000
# mean         0.706595
# std          0.245915
# min          0.060660
# 25%          0.515280
# 50%          0.739500
# 75%          0.945120
# max          1.000000
# Name: mvar44, dtype: float64
# =================================
#  mvar45
# count     37080
# unique        8
# top           0
# freq      34735
# Name: mvar45, dtype: object
# =================================
#  mvar46
# count     59397
# unique        6
# top           0
# freq      54493
# Name: mvar46, dtype: object
# =================================
#  mvar47
# count     83000
# unique        2
# top           C
# freq      52043
# Name: mvar47, dtype: object
# =================================
#  default_ind
# count    83000.000000
# mean         0.287410
# std          0.452557
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: default_ind, dtype: float64

# %%
df.replace('missing',np.NaN).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83000 entries, 0 to 82999
# Data columns (total 49 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   application_key  83000 non-null  int64
#  1   mvar1            83000 non-null  object
#  2   mvar2            77114 non-null  float64
#  3   mvar3            82465 non-null  float64
#  4   mvar4            82465 non-null  float64
#  5   mvar5            82465 non-null  float64
#  6   mvar6            63299 non-null  object
#  7   mvar7            75326 non-null  object
#  8   mvar8            63291 non-null  object
#  9   mvar9            71318 non-null  object
#  10  mvar10           82465 non-null  object
#  11  mvar11           36283 non-null  object
#  12  mvar12           68422 non-null  object
#  13  mvar13           73311 non-null  object
#  14  mvar14           83000 non-null  int64
#  15  mvar15           49481 non-null  object
#  16  mvar16           83000 non-null  object
#  17  mvar17           83000 non-null  object
#  18  mvar18           83000 non-null  object
#  19  mvar19           83000 non-null  object
#  20  mvar20           83000 non-null  object
#  21  mvar21           59538 non-null  float64
#  22  mvar22           52332 non-null  float64
#  23  mvar23           40689 non-null  float64
#  24  mvar24           63470 non-null  float64
#  25  mvar25           75138 non-null  object
#  26  mvar26           72071 non-null  object
#  27  mvar27           69350 non-null  object
#  28  mvar28           82465 non-null  object
#  29  mvar29           82465 non-null  object
#  30  mvar30           45012 non-null  object
#  31  mvar31           24461 non-null  object
#  32  mvar32           75138 non-null  object
#  33  mvar33           81131 non-null  float64
#  34  mvar34           83000 non-null  object
#  35  mvar35           83000 non-null  object
#  36  mvar36           83000 non-null  object
#  37  mvar37           83000 non-null  object
#  38  mvar38           83000 non-null  object
#  39  mvar39           83000 non-null  object
#  40  mvar40           17930 non-null  object
#  41  mvar41           25736 non-null  object
#  42  mvar42           80977 non-null  object
#  43  mvar43           83000 non-null  object
#  44  mvar44           74851 non-null  float64
#  45  mvar45           83000 non-null  object
#  46  mvar46           83000 non-null  object
#  47  mvar47           83000 non-null  object
#  48  default_ind      83000 non-null  int64
# dtypes: float64(10), int64(3), object(36)
# memory usage: 31.0+ MB

# %%
import missingno as msno
msno.matrix(df)

# %%
import missingno as msno
msno.matrix(df.replace("missing", np.NaN).replace("na", np.NaN))

# %%
df['mvar1'].dtype
# Out:
# dtype('O')
